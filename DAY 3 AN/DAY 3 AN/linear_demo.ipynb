# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# Input data
hours = np.array([[1], [2], [3], [4], [5]])   #2D array for hours
marks = np.array([35, 40, 45, 50, 55])   #1D array for marks
print(hours)
print(marks)
# Out:
# [[1]
#  [2]
#  [3]
#  [4]
#  [5]]
# [35 40 45 50 55]

# %%
print(hours.shape)
print(marks.shape)
# Out:
# (5, 1)
# (5,)

# %%
# Step 1: Create the model
model = LinearRegression()

# %%
# Step 2: Train the model
model.fit(hours, marks)
# Out:
# LinearRegression()

# %%
a = np.array([[6]])
print(a.shape)
# Out:
# (1, 1)

# %%
list_1 = [1,2]
list_1[0]
# Out:
# 1

# %%
# Step 3: Predict for 6 hours
predicted_6 = model.predict([[6]])
print(predicted_6)
print("📌 Predicted marks for 6 hours of study:", predicted_6[0])
# Out:
# [60.]
# 📌 Predicted marks for 6 hours of study: 60.0

# %%
# Step 3: Predict for 6 hours
predicted_7 = model.predict([[7]])
print("📌 Predicted marks for 6 hours of study:", predicted_7[0])
# Out:
# 📌 Predicted marks for 6 hours of study: 65.0

# %%
# Step 4: Predict on training data (for error & plot)
predicted_train = model.predict(hours)    #1,2,3,4,5

# %%
predicted_train
# Out:
# array([35., 40., 45., 50., 55.])

# %%
# Step 6: Plot the data and regression line
plt.figure(figsize=(8, 5))
plt.scatter(hours, marks, color='blue', label='Actual Marks')
plt.plot(hours, predicted_train, color='red', label='Regression Line')
plt.scatter(6, predicted_6, color='green', label='Prediction for 6 hrs', marker='*', s=100)
plt.xlabel("Hours Studied")
plt.ylabel("Marks Scored")
plt.title("Linear Regression - Hours vs Marks")
plt.legend()
plt.grid(True)
plt.show()
